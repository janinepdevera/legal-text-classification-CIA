# %% [markdown]
# # Multi-label Legal Text Classification for CIA

# %% [markdown]
# ## Models and Experiments

# %% [markdown]
# ### Preliminaries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import csv

# %%
from zipfile import ZipFile
from gensim.test.utils import common_texts
from gensim.models import Word2Vec
import gensim.downloader as api
from gensim.test.utils import datapath
from gensim.models import KeyedVectors
from nltk.tokenize import sent_tokenize, word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer 
from sklearn.feature_extraction.text import CountVectorizer 
from sklearn.metrics.pairwise import cosine_similarity
from numpy.linalg import norm

# %%
os.chdir("../..")
os.getcwd()
# Out:
# '/Users/janinedevera/Documents/School/MDS 2021-2023/Thesis/multilabel-legal-text-classification-CIA'

# %%
text = pd.read_csv("data/legal_texts_pipeline.csv")

# %%
text
# Out:
#       Unnamed: 0                                          file_name country  \
# 0              0  SG_Public Consultation Paper on Draft Amendmen...      SG
# 1              2  SG_Public Consultation Paper on Draft Amendmen...      SG
# 2              3  SG_Public Consultation Paper on Draft Amendmen...      SG
# 3              4  SG_Public Consultation Paper on Draft Amendmen...      SG
# 4              5  SG_Public Consultation Paper on Draft Amendmen...      SG
# ...          ...                                                ...     ...
# 3952        7806                  BN_Companies Act Chapter 39, 2016      BN
# 3953        7809                  BN_Companies Act Chapter 39, 2016      BN
# 3954        7811                  BN_Companies Act Chapter 39, 2016      BN
# 3955        7816                  BN_Companies Act Chapter 39, 2016      BN
# 3956        7828                  BN_Companies Act Chapter 39, 2016      BN
#
#                                                    text lang  length  \
# 0      V: PROCEDURES AND TIMEFRAME FOR SUBMITTING CO...   en     233
# 1      6 of the PSA, and such providers would theref...   en     274
# 2     s 48 and 48A to expand the powers of search an...   en      90
# 3      currently does not spell out the consequences...   en      86
# 4      on the regulation of letter boxes. Enhancing ...   en      29
# ...                                                 ...  ...     ...
# 3952   OF NUMBER OF MEMBERS BELOW LEGAL MINIMUM 31. ...   en      22
# 3953   AND ARTICLES 23. Effect of memorandum and art...   en      31
# 3954   OF COMPANIES 20. Restriction on registration ...   en      27
# 3955   OF ASSOCIATION 4. Mode of forming incorporate...   en      43
# 3956   ACT Enactment No. 25 of 1956 Amended by Enact...   en      46
#
#                                              text_clean
# 0     v procedur and timefram for submit comment mci...
# 1     psa provid would therefor requir postal servic...
# 2     48a expand power search arrest dispos letter r...
# 3     current spell consequ breach direct given mini...
# 4     regul letter box enhanc enforc power psa today...
# ...                                                 ...
# 3952  of number of member below legal minimum prohib...
# 3953  and articl effect memorandum articl money paya...
# 3954  of compani restrict registr compani certain na...
# 3955  of associ mode form incorpor compani requir re...
# 3956  act enact no amend enact no s 89/1957 s 99/195...
#
# [3957 rows x 7 columns]

# %%
defs = pd.read_csv("data/oecd_definitions_preprocess.csv")

# %%
defs
# Out:
#     Unnamed: 0 Main_Cat Sub_Cat  \
# 0            0        A     NaN
# 1            1        A      A1
# 2            2        A      A2
# 3            3        A      A3
# 4            4        A      A4
# 5            5        A      A5
# 6            6        B     NaN
# 7            7        B      B1
# 8            8        B      B2
# 9            9        B      B3
# 10          10        B      B4
# 11          11        C     NaN
# 12          12        C      C1
# 13          13        C      C2
# 14          14        C      C3
# 15          15        D      D1
# 16          16        D      D2
# 17          17        D      D3
#
#                                                  Text  length  \
# 0   Limiting the number of suppliers leads to the ...     118
# 1   Granting an exclusive right to produce a certa...     172
# 2   Licenses or permits required for operation nec...     176
# 3   Governments can limit the ability of certain s...      71
# 4   Regulations that raise the cost of entry to, o...     149
# 5   Regulations sometimes limit the flow of goods,...     142
# 6   Regulation can affect a supplier's ability to ...      50
# 7   Governments often regulate prices in tradition...     177
# 8   Regulations that restrict supplier's ability t...     141
# 9   Regulations setting standards often provide be...     193
# 10  At times, regulations have the effect of raisi...     215
# 11  Regulations can affect supplier behaviour by n...     138
# 12  When an industry or professional association t...     123
# 13  Regulations that require market participants t...     135
# 14  In many countries, particular suppliers or eco...      60
# 15  Regulations sometimes limit choices available ...      75
# 16  Regulations can make consumers more or less wi...      92
# 17  When governments deregulate and introduce mark...      88
#
#                                            text_clean
# 0   limit number supplier lead risk market power c...
# 1   grant exclus right produc certain good provid ...
# 2   licens permit requir oper necessarili restrict...
# 3   govern limit abil certain supplier particip bu...
# 4   regul rais cost entri exit market tend discour...
# 5   regul sometim limit flow good servic capit and...
# 6   regul affect supplier 's abil compet varieti w...
# 7   govern often regul price tradit monopoli secto...
# 8   regul restrict supplier 's abil advertis marke...
# 9   regul set standard often provid benefit consum...
# 10  at time regul effect rais cost supplier rel ot...
# 11  regul affect supplier behaviour chang abil com...
# 12  when industri profession associ take full resp...
# 13  regul requir market particip publish inform pr...
# 14  in mani countri particular supplier econom sec...
# 15  regul sometim limit choic avail consum for exa...
# 16  regul make consum le will switch supplier affe...
# 17  when govern deregul introduc market previous e...

# %% [markdown]
# ### I. Pre-Trained Word Embeddings

# %% [markdown]
# #### A. GloVe

# %% [markdown]
# Document embedding matrix

# %%
# load GloVe embeddings
dims = 300
f = open(f'data/glove/glove.6B.{dims}d.txt') # download GloVe and save in data folder

embed_matrix = pd.read_table(
    f, sep = " ", index_col = 0, 
    header = None, quoting = csv.QUOTE_NONE
)

embed_matrix.shape
# Out:
# (400000, 300)

# %%
# document feature matrix 
vectorizer = TfidfVectorizer()
text_dfm = vectorizer.fit_transform(text['text_clean'])
text_dfm.shape
# Out:
# (3957, 10829)

# %%
# document embedding matrix
def doc_matrix(dfm):
    common_features = set(embed_matrix.index) & set(vectorizer.get_feature_names_out())
    vocab_ids = [vectorizer.vocabulary_[x] for x in common_features]
    matrix = dfm[:,vocab_ids].dot(embed_matrix.loc[common_features,])
    return matrix

# %%
text_doc_matrix = doc_matrix(text_dfm)
text_doc_matrix.shape
# Out:
# /var/folders/rd/n9w0gpv53y72x5k9wk3hp63w0000gn/T/ipykernel_54972/1503737854.py:5: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   matrix = dfm[:,vocab_ids].dot(embed_matrix.loc[common_features,])
# (3957, 300)

# %%
defs_dfm = vectorizer.fit_transform(defs['text_clean'])
defs_dfm.shape
# Out:
# (18, 505)

# %%
defs_doc_matrix = doc_matrix(defs_dfm)
defs_doc_matrix.shape
# Out:
# /var/folders/rd/n9w0gpv53y72x5k9wk3hp63w0000gn/T/ipykernel_54972/1503737854.py:5: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   matrix = dfm[:,vocab_ids].dot(embed_matrix.loc[common_features,])
# (18, 300)

# %% [markdown]
# Cosine similarities

# %%
def cos_sim(a, b):
    dot_product = np.dot(a, b)
    norm_a = np.linalg.norm(a)
    norm_b = np.linalg.norm(b)
    return dot_product / (norm_a * norm_b)

# %%
docs = []
for i in range(len(text_doc_matrix)):
    scores = []
    for j in range(len(defs_doc_matrix)):
        A = text_doc_matrix[i]
        B = defs_doc_matrix[j]
        scores += [(cos_sim(A,B)+1)/(1+1)] # centered 
    docs += [scores]

# %%
scores_df = pd.DataFrame(docs, columns = ["A", "A1", "A2", "A3", "A4", "A5",
                                   "B", "B1", "B2", "B3", "B4",
                                   "C", "C1", "C2", "C3",
                                   "D1", "D2", "D3"])

# %%
scores_df
# Out:
#              A        A1        A2        A3        A4        A5         B  \
# 0     0.878472  0.878373  0.896583  0.826655  0.871035  0.875192  0.855002
# 1     0.854552  0.840158  0.882529  0.841466  0.870895  0.855248  0.853953
# 2     0.871088  0.843893  0.874042  0.844152  0.874516  0.875603  0.869060
# 3     0.881344  0.852856  0.886959  0.859507  0.877802  0.879161  0.880185
# 4     0.886487  0.839401  0.876812  0.823139  0.859429  0.868762  0.861264
# ...        ...       ...       ...       ...       ...       ...       ...
# 3952  0.850380  0.820828  0.856978  0.837702  0.840123  0.867546  0.840383
# 3953  0.793783  0.805595  0.825166  0.783915  0.778836  0.800209  0.779834
# 3954  0.799791  0.781637  0.814314  0.767413  0.801416  0.809280  0.787403
# 3955  0.729542  0.737423  0.778395  0.742421  0.774242  0.750517  0.742531
# 3956  0.708047  0.638856  0.693587  0.665391  0.711294  0.699907  0.687562
#
#             B1        B2        B3        B4         C        C1        C2  \
# 0     0.854243  0.877407  0.892135  0.875251  0.879628  0.878576  0.875328
# 1     0.837029  0.867685  0.868617  0.862237  0.859432  0.873476  0.856893
# 2     0.868521  0.851324  0.887944  0.872032  0.870637  0.881412  0.853884
# 3     0.866065  0.860409  0.897168  0.877538  0.866631  0.886514  0.853792
# 4     0.859265  0.833621  0.886639  0.887101  0.857925  0.879365  0.855495
# ...        ...       ...       ...       ...       ...       ...       ...
# 3952  0.860588  0.808367  0.866152  0.856999  0.827610  0.845249  0.835206
# 3953  0.789568  0.792049  0.801657  0.800647  0.824109  0.819796  0.811023
# 3954  0.789206  0.764392  0.817942  0.814695  0.784547  0.820500  0.760035
# 3955  0.747311  0.736132  0.753209  0.742977  0.751476  0.754248  0.750473
# 3956  0.716474  0.631094  0.696598  0.712057  0.674215  0.699614  0.692444
#
#             C3        D1        D2        D3
# 0     0.848875  0.881012  0.872898  0.907295
# 1     0.845093  0.851226  0.851742  0.855663
# 2     0.857591  0.854753  0.853570  0.863468
# 3     0.855139  0.856606  0.879028  0.878354
# 4     0.839462  0.842558  0.876877  0.876377
# ...        ...       ...       ...       ...
# 3952  0.830421  0.836647  0.835412  0.834582
# 3953  0.828944  0.767436  0.780723  0.801196
# 3954  0.770257  0.798057  0.800242  0.815425
# 3955  0.730215  0.725753  0.739636  0.726420
# 3956  0.676700  0.688938  0.721102  0.710013
#
# [3957 rows x 18 columns]

# %%
text
# Out:
#       Unnamed: 0                                          file_name country  \
# 0              0  SG_Public Consultation Paper on Draft Amendmen...      SG
# 1              2  SG_Public Consultation Paper on Draft Amendmen...      SG
# 2              3  SG_Public Consultation Paper on Draft Amendmen...      SG
# 3              4  SG_Public Consultation Paper on Draft Amendmen...      SG
# 4              5  SG_Public Consultation Paper on Draft Amendmen...      SG
# ...          ...                                                ...     ...
# 3952        7806                  BN_Companies Act Chapter 39, 2016      BN
# 3953        7809                  BN_Companies Act Chapter 39, 2016      BN
# 3954        7811                  BN_Companies Act Chapter 39, 2016      BN
# 3955        7816                  BN_Companies Act Chapter 39, 2016      BN
# 3956        7828                  BN_Companies Act Chapter 39, 2016      BN
#
#                                                    text lang  length  \
# 0      V: PROCEDURES AND TIMEFRAME FOR SUBMITTING CO...   en     233
# 1      6 of the PSA, and such providers would theref...   en     274
# 2     s 48 and 48A to expand the powers of search an...   en      90
# 3      currently does not spell out the consequences...   en      86
# 4      on the regulation of letter boxes. Enhancing ...   en      29
# ...                                                 ...  ...     ...
# 3952   OF NUMBER OF MEMBERS BELOW LEGAL MINIMUM 31. ...   en      22
# 3953   AND ARTICLES 23. Effect of memorandum and art...   en      31
# 3954   OF COMPANIES 20. Restriction on registration ...   en      27
# 3955   OF ASSOCIATION 4. Mode of forming incorporate...   en      43
# 3956   ACT Enactment No. 25 of 1956 Amended by Enact...   en      46
#
#                                              text_clean
# 0     v procedur and timefram for submit comment mci...
# 1     psa provid would therefor requir postal servic...
# 2     48a expand power search arrest dispos letter r...
# 3     current spell consequ breach direct given mini...
# 4     regul letter box enhanc enforc power psa today...
# ...                                                 ...
# 3952  of number of member below legal minimum prohib...
# 3953  and articl effect memorandum articl money paya...
# 3954  of compani restrict registr compani certain na...
# 3955  of associ mode form incorpor compani requir re...
# 3956  act enact no amend enact no s 89/1957 s 99/195...
#
# [3957 rows x 7 columns]

# %%
text_scores_glove = pd.merge(text, scores_df, left_index=True, right_index=True)
text_scores_glove.drop(['text'], axis=1, inplace=True)

# %% [markdown]
# #### B. Word2Vec

# %% [markdown]
# Document embedding matrix (from SigmaLaw word2vec trained from legal corpus)

# %%
w2v_law = KeyedVectors.load_word2vec_format("data/sigma-lemmatized-legal/legallemmatextreplacewithnnp.bin", binary=True, unicode_errors='ignore') 
w2v_law.vectors.shape
# Out:
# (52431, 200)

# %%
def doc_matrix_w2v(dfm):
    words = set(vectorizer.get_feature_names_out())
    text_vocab = list(words)

    common_features = []
    for word in text_vocab:
        if word in w2v_law:
            common_features += [word]

    embed_common=np.empty((0,200))
    for word in words:
        if word in w2v_law:
            embed_common=np.vstack([embed_common, w2v_law[word]])

    vocab_ids = [vectorizer.vocabulary_[x] for x in common_features]
    doc_matrix_w2v = dfm[:,vocab_ids].dot(embed_common)

    return doc_matrix_w2v

# %%
text_dfm = vectorizer.fit_transform(text['text_clean'])
text_doc_matrix = doc_matrix_w2v(text_dfm)
text_doc_matrix.shape
# Out:
# (3957, 200)

# %%
defs_dfm = vectorizer.fit_transform(defs['text_clean'])
defs_doc_matrix = doc_matrix_w2v(defs_dfm)
defs_doc_matrix.shape
# Out:
# (18, 200)

# %% [markdown]
# Full sample

# %%
# get corpus vocabulary
text_dfm = vectorizer.fit_transform(text['text_clean'])
words = set(vectorizer.get_feature_names_out())
text_vocab = list(words)

# %%
# get common features between vocab & w2v legal
common_features = []
for word in text_vocab:
    if word in w2v_law:
        common_features += [word]
len(common_features)
# Out:
# 4510

# %%
# get embedding matrix of common features
embed_common=np.empty((0,200))
for word in words:
    if word in w2v_law:
        embed_common=np.vstack([embed_common, w2v_law[word]])
embed_common.shape
# Out:
# (4510, 200)

# %%
vocab_ids = [vectorizer.vocabulary_[x] for x in common_features] # vocab id of common features
text_doc_matrix = text_dfm[:,vocab_ids].dot(embed_common)
text_doc_matrix.shape
# Out:
# (3957, 200)

# %% [markdown]
# Cosine similarities

# %%
docs = []
for i in range(len(text_doc_matrix)):
    scores = []
    for j in range(len(defs_doc_matrix)):
        A = text_doc_matrix[i]
        B = defs_doc_matrix[j]
        scores += [(cos_sim(A,B)+1)/(1+1)] # centered 
    docs += [scores]

# %%
scores_df
# Out:
#              A        A1        A2        A3        A4        A5         B  \
# 0     0.536525  0.459559  0.537989  0.463001  0.523567  0.498330  0.455624
# 1     0.665215  0.575294  0.729426  0.705163  0.676475  0.668700  0.618173
# 2     0.580048  0.527133  0.670397  0.663248  0.586911  0.602800  0.585329
# 3     0.567670  0.501511  0.570694  0.714365  0.539091  0.583048  0.613908
# 4     0.678133  0.682478  0.729480  0.646756  0.682879  0.712383  0.605551
# ...        ...       ...       ...       ...       ...       ...       ...
# 3952  0.551197  0.452049  0.560255  0.653386  0.565066  0.555950  0.597086
# 3953  0.584132  0.467479  0.534105  0.616220  0.504181  0.530071  0.540425
# 3954  0.614141  0.568402  0.646899  0.650706  0.586871  0.618491  0.575393
# 3955  0.560857  0.531230  0.617293  0.625084  0.545608  0.586323  0.577739
# 3956  0.463408  0.506805  0.518720  0.531925  0.458062  0.528615  0.467814
#
#             B1        B2        B3        B4         C        C1        C2  \
# 0     0.465707  0.517841  0.471030  0.507956  0.499249  0.498103  0.608890
# 1     0.589117  0.657095  0.592675  0.713742  0.628497  0.714595  0.713065
# 2     0.575341  0.615143  0.539514  0.630336  0.551113  0.647147  0.602205
# 3     0.615573  0.568935  0.568260  0.646162  0.558265  0.623368  0.630092
# 4     0.568417  0.706246  0.592776  0.707106  0.644615  0.691720  0.669281
# ...        ...       ...       ...       ...       ...       ...       ...
# 3952  0.665313  0.517814  0.574170  0.585063  0.554840  0.553634  0.599394
# 3953  0.553892  0.530312  0.453443  0.605633  0.598396  0.530186  0.606739
# 3954  0.569283  0.625319  0.538354  0.662443  0.559164  0.605036  0.632609
# 3955  0.541715  0.565509  0.519056  0.604129  0.531622  0.611913  0.609999
# 3956  0.455271  0.527803  0.455208  0.534599  0.445067  0.577953  0.515818
#
#             C3        D1        D2        D3
# 0     0.344464  0.594111  0.527763  0.637100
# 1     0.554240  0.641008  0.662267  0.554308
# 2     0.612300  0.565240  0.562154  0.481261
# 3     0.595794  0.538882  0.599728  0.587790
# 4     0.657721  0.635652  0.601724  0.495907
# ...        ...       ...       ...       ...
# 3952  0.527647  0.546437  0.589858  0.498585
# 3953  0.508496  0.498931  0.569075  0.493146
# 3954  0.543255  0.584565  0.566902  0.532200
# 3955  0.572086  0.518065  0.511973  0.455983
# 3956  0.564255  0.502150  0.461898  0.483476
#
# [3957 rows x 18 columns]

# %%
text_scores_legalw2v = pd.merge(text, scores_df, left_index=True, right_index=True)
text_scores_legalw2v.drop(['text'], axis=1, inplace=True)

# %%
with pd.ExcelWriter('baseline_scores.xlsx') as writer:
    text_scores_glove[-].to_excel(writer, sheet_name='GloVe')
    text_scores_legalw2v.to_excel(writer, sheet_name='LegalW2V')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/janinedevera/Documents/School/MDS 2021-2023/Thesis/multilabel-legal-text-classification-CIA/src/python/models.ipynb Cell 42 in 2
#       <a href='vscode-notebook-cell:/Users/janinedevera/Documents/School/MDS%202021-2023/Thesis/multilabel-legal-text-classification-CIA/src/python/models.ipynb#Y122sZmlsZQ%3D%3D?line=0'>1</a> with pd.ExcelWriter('baseline_scores.xlsx') as writer:
# ----> <a href='vscode-notebook-cell:/Users/janinedevera/Documents/School/MDS%202021-2023/Thesis/multilabel-legal-text-classification-CIA/src/python/models.ipynb#Y122sZmlsZQ%3D%3D?line=1'>2</a>     text_scores_glove[-'text'].to_excel(writer, sheet_name='GloVe')
#       <a href='vscode-notebook-cell:/Users/janinedevera/Documents/School/MDS%202021-2023/Thesis/multilabel-legal-text-classification-CIA/src/python/models.ipynb#Y122sZmlsZQ%3D%3D?line=2'>3</a>     text_scores_legalw2v[-'text'].to_excel(writer, sheet_name='LegalW2V')
#
# TypeError: bad operand type for unary -: 'str'
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# /Users/janinedevera/Documents/School/MDS 2021-2023/Thesis/multilabel-legal-text-classification-CIA/src/python/models.ipynb Cell 42 in 3
#       <a href='vscode-notebook-cell:/Users/janinedevera/Documents/School/MDS%202021-2023/Thesis/multilabel-legal-text-classification-CIA/src/python/models.ipynb#Y122sZmlsZQ%3D%3D?line=0'>1</a> with pd.ExcelWriter('baseline_scores.xlsx') as writer:
#       <a href='vscode-notebook-cell:/Users/janinedevera/Documents/School/MDS%202021-2023/Thesis/multilabel-legal-text-classification-CIA/src/python/models.ipynb#Y122sZmlsZQ%3D%3D?line=1'>2</a>     text_scores_glove[-'text'].to_excel(writer, sheet_name='GloVe')
# ----> <a href='vscode-notebook-cell:/Users/janinedevera/Documents/School/MDS%202021-2023/Thesis/multilabel-legal-text-classification-CIA/src/python/models.ipynb#Y122sZmlsZQ%3D%3D?line=2'>3</a>     text_scores_legalw2v[-'text'].to_excel(writer, sheet_name='LegalW2V')
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/io/excel/_base.py:1201, in ExcelWriter.__exit__(self, exc_type, exc_value, traceback)
#    1200 def __exit__(self, exc_type, exc_value, traceback):
# -> 1201     self.close()
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/io/excel/_base.py:1205, in ExcelWriter.close(self)
#    1203 def close(self) -> None:
#    1204     """synonym for save, to make it more file-like"""
# -> 1205     self.save()
#    1206     self.handles.close()
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/io/excel/_openpyxl.py:81, in OpenpyxlWriter.save(self)
#      77 def save(self):
#      78     """
#      79     Save workbook to disk.
#      80     """
# ---> 81     self.book.save(self.handles.handle)
#      82     if "r+" in self.mode and not isinstance(self.handles.handle, mmap.mmap):
#      83         # truncate file to the written content
#      84         self.handles.handle.truncate()
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/openpyxl/workbook/workbook.py:386, in Workbook.save(self, filename)
#     384 if self.write_only and not self.worksheets:
#     385     self.create_sheet()
# --> 386 save_workbook(self, filename)
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/openpyxl/writer/excel.py:294, in save_workbook(workbook, filename)
#     292 workbook.properties.modified = datetime.datetime.utcnow()
#     293 writer = ExcelWriter(workbook, archive)
# --> 294 writer.save()
#     295 return True
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/openpyxl/writer/excel.py:275, in ExcelWriter.save(self)
#     273 def save(self):
#     274     """Write data into the archive."""
# --> 275     self.write_data()
#     276     self._archive.close()
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/openpyxl/writer/excel.py:89, in ExcelWriter.write_data(self)
#      87 writer = WorkbookWriter(self.workbook)
#      88 archive.writestr(ARC_ROOT_RELS, writer.write_root_rels())
# ---> 89 archive.writestr(ARC_WORKBOOK, writer.write())
#      90 archive.writestr(ARC_WORKBOOK_RELS, writer.write_rels())
#      92 self._merge_vba()
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/openpyxl/workbook/_writer.py:150, in WorkbookWriter.write(self)
#     148 self.write_names()
#     149 self.write_pivots()
# --> 150 self.write_views()
#     151 self.write_refs()
#     153 return tostring(self.package.to_tree())
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/openpyxl/workbook/_writer.py:137, in WorkbookWriter.write_views(self)
#     136 def write_views(self):
# --> 137     active = get_active_sheet(self.wb)
#     138     if self.wb.views:
#     139         self.wb.views[0].activeTab = active
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/openpyxl/workbook/_writer.py:35, in get_active_sheet(wb)
#      33 visible_sheets = [idx for idx, sheet in enumerate(wb._sheets) if sheet.sheet_state == "visible"]
#      34 if not visible_sheets:
# ---> 35     raise IndexError("At least one sheet must be visible")
#      37 idx = wb._active_sheet_index
#      38 sheet = wb.active
#
# IndexError: At least one sheet must be visible
